# %%
import statistical_analysis as sa
import datetime

# %%
sa.simple_timeseries(url="https://sundowner.colorado.edu/weather/atoc1/wxobs20211230.txt", start_date = datetime.date(2006,4,25),
end_date = datetime.date(2006,6,25), column_name="Out_Hum")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 sa.simple_timeseries(url="https://sundowner.colorado.edu/weather/atoc1/wxobs20211230.txt", start_date = datetime.date(2006,4,25),
#       2 end_date = datetime.date(2006,6,25), column_name="Out_Hum")
#
# File c:\Users\moenc\Documents\Classes\MENV\Spring 2026\SPDAV\ATOC4815\Final_project\statistical_analysis.py:59, in simple_timeseries(url, start_date, end_date, column_name)
#      55 # print(df.index.dtype())
#      56 # print(time, temperature)
#      58 plt.figure(figsize=(12,3))
# ---> 59 plt.plot(time, column_name, marker='o', color='steelblue', linewidth=2)
#      60 plt.xlabel('Time')
#      61 plt.ylabel(column_name)
#
# File c:\Users\moenc\miniconda3\envs\atoc-2025-lite\Lib\site-packages\matplotlib\pyplot.py:3838, in plot(scalex, scaley, data, *args, **kwargs)
# ...
